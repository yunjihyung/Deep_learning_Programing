# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r'..\dataset\신체검사데이터.csv',encoding='cp949')
df.columns = names = ['num','date','chest','arm','height','waist','crotch','head','foot','weight']
df
# Out:
# C:\Users\yunji\AppData\Local\Temp\ipykernel_12820\1009295356.py:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'..\dataset\신체검사데이터.csv',encoding='cp949')
#            num      date  chest   arm  height           waist  crotch  head  \
# 0            1  20140106   96.3  92.6   185.5            82.5    83.8  57.1
# 1            2      2013  101.9  83.8   167.2            81.2    74.4  55.0
# 2            3  20140106   99.5  89.6   179.9            99.2    84.2  56.3
# 3            4      2013   98.6  85.5   171.4            85.9    76.4  54.5
# 4            5  20140106   94.7  88.1   176.9            78.3    79.7  58.5
# ...        ...       ...    ...   ...     ...             ...     ...   ...
# 167975  167979  20170131  100.6  86.4   173.2  86.7 (34.1 in)    77.1  56.9
# 167976  167980  20170131   97.9  82.7   166.3  90.5 (35.6 in)    73.4  61.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167980 entries, 0 to 167979
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   num     167980 non-null  int64
#  1   date    167980 non-null  int64
#  2   chest   167980 non-null  float64
#  3   arm     167980 non-null  float64
#  4   height  167980 non-null  float64
#  5   waist   167980 non-null  object
#  6   crotch  167980 non-null  float64
#  7   head    167980 non-null  float64
#  8   foot    167980 non-null  float64
#  9   weight  167980 non-null  float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.8+ MB

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['waist'] = df['waist'].map(lambda x :str(x))
df['waist']
# Out:
# 0                   82.5
# 1                   81.2
# 2                   99.2
# 3                   85.9
# 4                   78.3
#                ...
# 167975    86.7 (34.1 in)
# 167976    90.5 (35.6 in)
# 167977    94.3 (37.1 in)
# 167978    75.9 (29.9 in)
# 167979    73.0 (28.7 in)
# Name: waist, Length: 167980, dtype: object

# %%
df['waist'] = df['waist'].str[:4].map(lambda x : float(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167980 entries, 0 to 167979
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   num     167980 non-null  int64
#  1   date    167980 non-null  int64
#  2   chest   167980 non-null  float64
#  3   arm     167980 non-null  float64
#  4   height  167980 non-null  float64
#  5   waist   167980 non-null  float64
#  6   crotch  167980 non-null  float64
#  7   head    167980 non-null  float64
#  8   foot    167980 non-null  float64
#  9   weight  167980 non-null  float64
# dtypes: float64(8), int64(2)
# memory usage: 12.8 MB

# %%
df = df[['chest','arm','height','waist','crotch','head','foot','weight']]
df
# Out:
#         chest   arm  height  waist  crotch  head  foot  weight
# 0        96.3  92.6   185.5   82.5    83.8  57.1  28.5    73.2
# 1       101.9  83.8   167.2   81.2    74.4  55.0  24.2    65.1
# 2        99.5  89.6   179.9   99.2    84.2  56.3  28.1    93.2
# 3        98.6  85.5   171.4   85.9    76.4  54.5  27.4    71.6
# 4        94.7  88.1   176.9   78.3    79.7  58.5  26.5    67.1
# ...       ...   ...     ...    ...     ...   ...   ...     ...
# 167975  100.6  86.4   173.2   86.7    77.1  56.9  27.1    73.7
# 167976   97.9  82.7   166.3   90.5    73.4  61.5  28.8    70.7
# 167977   97.9  87.2   175.2   94.3    83.1  57.1  27.6    78.7
# 167978   85.3  86.8   173.6   75.9    76.6  57.6  24.3    57.4
# 167979   86.6  88.3   175.8   73.0    77.8  56.3  26.1    51.7
#
# [167980 rows x 8 columns]

# %%
df.describe()
#기술통계량
# Out:
#                chest            arm         height          waist  \
# count  167980.000000  167980.000000  167980.000000  167980.000000
# mean       95.592957      87.307860     174.689987      86.420761
# std         9.186797       2.736999       5.448835      11.175754
# min        74.900000      77.100000     153.600000      41.300000
# 25%        88.800000      85.400000     170.900000      78.000000
# 50%        94.500000      87.200000     174.600000      85.000000
# 75%       101.300000      89.100000     178.300000      93.500000
# max       139.900000      99.600000     198.400000     160.000000
#
#               crotch           head           foot         weight
# count  167980.000000  167980.000000  167980.000000  167980.000000
# mean       79.339203      58.112691      26.833369      72.155234
# std         3.787552       9.819429       1.397705      13.741908
# min         5.900000      52.000000       1.000000       0.000000
# ...

# %%
df.hist(figsize= (20,20))
# Out:
# array([[<Axes: title={'center': 'chest'}>,
#         <Axes: title={'center': 'arm'}>,
#         <Axes: title={'center': 'height'}>],
#        [<Axes: title={'center': 'waist'}>,
#         <Axes: title={'center': 'crotch'}>,
#         <Axes: title={'center': 'head'}>],
#        [<Axes: title={'center': 'foot'}>,
#         <Axes: title={'center': 'weight'}>, <Axes: >]], dtype=object)

# %%
df.hist(figsize= (20,20))
#이상치 확인
# Out:
# array([[<Axes: title={'center': 'chest'}>,
#         <Axes: title={'center': 'arm'}>,
#         <Axes: title={'center': 'height'}>],
#        [<Axes: title={'center': 'waist'}>,
#         <Axes: title={'center': 'crotch'}>,
#         <Axes: title={'center': 'head'}>],
#        [<Axes: title={'center': 'foot'}>,
#         <Axes: title={'center': 'weight'}>, <Axes: >]], dtype=object)

# %%
df = df[df['head'] < 1000]

# %%
df.describe()
# Out:
#                chest            arm         height          waist  \
# count  167979.000000  167979.000000  167979.000000  167979.000000
# mean       95.593002      87.307843     174.689958      86.420832
# std         9.186806       2.736998       5.448837      11.175749
# min        74.900000      77.100000     153.600000      41.300000
# 25%        88.800000      85.400000     170.900000      78.000000
# 50%        94.500000      87.200000     174.600000      85.000000
# 75%       101.300000      89.100000     178.300000      93.500000
# max       139.900000      99.600000     198.400000     160.000000
#
#               crotch           head           foot         weight
# count  167979.000000  167979.000000  167979.000000  167979.000000
# mean       79.339203      58.089237      26.833365      72.155664
# std         3.787563       2.003001       1.397708      13.740821
# min         5.900000      52.000000       1.000000       0.000000
# ...

# %%
sns.heatmap(df.corr(),annot=True, cmap='coolwarm',linewidths=0.2)
# Out:
# <Axes: >

# %%
df.to_csv(r'..\dataset\preprocessed.csv',index=False)
